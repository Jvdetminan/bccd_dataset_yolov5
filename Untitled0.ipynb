# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/dataset_bccd'

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd /content/yolov5
# !pip install -r requirements.txt
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17680, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 17680 (delta 27), reused 18 (delta 18), pack-reused 17628 (from 3)
# Receiving objects: 100% (17680/17680), 17.07 MiB | 25.26 MiB/s, done.
# Resolving deltas: 100% (12014/12014), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.2 MB/s eta 0:00:00
# ...

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/dataset_bccd/train/images | head   #confidence
# Out:
# BloodImage_00001_jpg.rf.0486829b3baf12b2cbbef9ca7cd0e8d0.jpg
# BloodImage_00001_jpg.rf.97652f90373e266767a649b45afd875f.jpg
# BloodImage_00001_jpg.rf.dd77c8c00b0def88adb249d090097881.jpg
# BloodImage_00002_jpg.rf.7aa843b277da23e5905ab236844b38b6.jpg
# BloodImage_00002_jpg.rf.9b8608950e9ab89be9c47cd2a9ef20b7.jpg
# BloodImage_00002_jpg.rf.ead3d21ba4067e9610c8b15b2b1869a6.jpg
# BloodImage_00003_jpg.rf.1d0bcc62f8937fc1cc4b5ecf76fc79c7.jpg
# BloodImage_00003_jpg.rf.50c29a5cf94f5cd4d5ebb30b16a38bed.jpg
# BloodImage_00003_jpg.rf.8562ceda7c83e7b9a7ba5a92a6e0c451.jpg
# BloodImage_00005_jpg.rf.38772d61a2749bb555ccd5930dba4b00.jpg

# %% [markdown]
# ### **train**

# %%
# !python train.py \
  --img 416 \
  --batch 16 \
  --epochs 25 \
  --data "/content/drive/MyDrive/Colab Notebooks/dataset_bccd/data.yaml"  \
  --weights yolov5s.pt \
  --name yolov5s_custom \
  --cache
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-11-02 14:24:20.897030: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762093460.928800    1400 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
from IPython.display import Image, display

display(Image(filename='/content/yolov5/runs/train/yolov5s_custom/results.png', width=1000))

# %%
# %ls runs/train/yolov5s_custom/weights
# Out:
# best.pt  last.pt

# %%
# %cd /content/yolov5/
# !python detect.py --weights runs/train/yolov5s_custom/weights/best.pt --img 416 --conf 0.35 --source /content/drive/MyDrive/Colab\ Notebooks/dataset_bccd/test/images/
# Out:
# /content/yolov5
# detect: weights=['runs/train/yolov5s_custom/weights/best.pt'], source=/content/drive/MyDrive/Colab Notebooks/dataset_bccd/test/images/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-445-gb4bfb5a9 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/36 /content/drive/MyDrive/Colab Notebooks/dataset_bccd/test/images/BloodImage_00038_jpg.rf.e5937056c6b0acfbd0e864c73b159adf.jpg: 416x416 1 Platelets, 29 RBCs, 1 WBC, 7.2ms
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp2/*.jpg')[:10]: #assuming JPG
    display(Image(filename=imageName))
